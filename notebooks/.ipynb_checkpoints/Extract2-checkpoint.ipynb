# %%
import sys
print(sys.executable)
# Out:
# /home/maxime/dev/python/sndx/.venv/bin/python3.12

# %%
import os
import time
import asyncio
import sndx
from sndx import Scrapper
from pathlib import Path
from datetime import timedelta
from pyppeteer import launch
from queue import Queue
import yaml
import re

CHROMIUM_PATH = os.environ.get("CHROMIUM_PATH")
ROOT_URL = "https://vod.catalogue-crc.org"
CATEGORIES_URL = "https://vod.catalogue-crc.org/categorie.html"
REQUEST_DELAY = 0

def parse_duration(s: str) -> int:
    parts = list(map(int, s.split(":")))
    if len(parts) == 3:
        h, m, sec = parts
    elif len(parts) == 2:
        h = 0
        m, sec = parts
    else:
        raise ValueError(f"Invalid duration format: {s}")

    seconds = h * 3600 + m * 60 + sec
    return timedelta(seconds=seconds)



def safe_filename(s):
    s = s.strip()
    s = re.sub(r"[^A-Za-z0-9._-]+", "_", s)
    return s or "file"

# %%
profile = "sndx-profile-1"

with sndx.Sink() as sink:
    async with sndx.RecordingScrapper(profile, sink, headless=False) as scrapper:
        print("Doing stuff")
        await asyncio.sleep(3)
        print("Stuff finished")
# Out:
# Opening sink sndx-sjhnrg
# [RecordingScrapper-ZNxe4w] Starting with profile [sndx-profile-1] and sink [sndx-sjhnrg]...
# Closing sink sndx-sjhnrg
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[168], line 4
#       1 profile = "sndx-profile-1"
#       3 with sndx.Sink() as sink:
# ----> 4     async with sndx.RecordingScrapper(profile, sink, headless=False) as scrapper:
#       5         print("Doing stuff")
#       6         await asyncio.sleep(3)
#
# File ~/dev/python/sndx/src/sndx/__init__.py:121, in Scrapper.__aenter__(self)
#     120 async def __aenter__(self):
# --> 121     await self.open()
#     122     return self
#
# File ~/dev/python/sndx/src/sndx/__init__.py:176, in RecordingScrapper.open(self)
#     174 async def open(self):
#     175     print(f"[RecordingScrapper-{self.id}] Starting with profile [{self.profile_id}] and sink [{self.sink.name}]...")
# --> 176     self.browser = await launch(
#     177         headless=self.headless,
#     178         executablePath=CHROMIUM_PATH,
#     179         userDataDir=self.profile_path,
#     180         args= [
#     181             "--autoplay-policy=no-user-gesture-required",
#     182             f"--audio-output-sink={self.sink.name}",
#     183         ])
#     184     pages = await self.browser.pages()
#     185     self.page = pages[0]
#
# File ~/dev/python/sndx/.venv/lib/python3.12/site-packages/pyppeteer/launcher.py:307, in launch(options, **kwargs)
#     239 async def launch(options: dict = None, **kwargs: Any) -> Browser:
#     240     """Start chrome process and return :class:`~pyppeteer.browser.Browser`.
#     241     This function is a shortcut to :meth:`Launcher(options, **kwargs).launch`.
#     242     Available options are:
#    (...)    305         option with extreme caution.
#     306     """
# --> 307     return await Launcher(options, **kwargs).launch()
#
# File ~/dev/python/sndx/.venv/lib/python3.12/site-packages/pyppeteer/launcher.py:168, in Launcher.launch(self)
#     165         signal.signal(signal.SIGHUP, _close_process)
#     167 connectionDelay = self.slowMo
# --> 168 self.browserWSEndpoint = get_ws_endpoint(self.url)
#     169 logger.info(f'Browser listening on: {self.browserWSEndpoint}')
#     170 self.connection = Connection(self.browserWSEndpoint, self._loop, connectionDelay, )
#
# File ~/dev/python/sndx/.venv/lib/python3.12/site-packages/pyppeteer/launcher.py:234, in get_ws_endpoint(url)
#     232     except (URLError, HTTPException):
#     233         pass
# --> 234     time.sleep(0.1)
#     236 return data['webSocketDebuggerUrl']
#
# File ~/dev/python/sndx/.venv/lib/python3.12/site-packages/pyppeteer/launcher.py:153, in Launcher.launch.<locals>._close_process(*args, **kwargs)
#     151 def _close_process(*args: Any, **kwargs: Any) -> None:
#     152     if not self.chromeClosed:
# --> 153         self._loop.run_until_complete(self.killChrome())
#
# File /nix/store/jd20rkmqmkfkcvk2wl2lmzz7acq4svlr-python3-3.12.12/lib/python3.12/asyncio/base_events.py:667, in BaseEventLoop.run_until_complete(self, future)
#     656 """Run until the Future is done.
#     657
#     658 If the argument is a coroutine, it is wrapped in a Task.
#    (...)    664 Return the Future's result, or raise its exception.
#     665 """
#     666 self._check_closed()
# --> 667 self._check_running()
#     669 new_task = not futures.isfuture(future)
#     670 future = tasks.ensure_future(future, loop=self)
#
# File /nix/store/jd20rkmqmkfkcvk2wl2lmzz7acq4svlr-python3-3.12.12/lib/python3.12/asyncio/base_events.py:626, in BaseEventLoop._check_running(self)
#     624 def _check_running(self):
#     625     if self.is_running():
# --> 626         raise RuntimeError('This event loop is already running')
#     627     if events._get_running_loop() is not None:
#     628         raise RuntimeError(
#     629             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running

# %%
def cleanup_url(url):
    return url.split("?")[0].split("#")[0]

def is_category_url(url):
    return url.startswith("https://vod.catalogue-crc.org/categorie/")

def is_serie_url(url):
    return url.startswith("https://vod.catalogue-crc.org/serie/")

def is_recording_url(url):
    return url.startswith("https://vod.catalogue-crc.org/enregistrement/")


class Link:
    def __init__(self, url, text):
        self.url = url
        self.text = text

    def __repr__(self):
        return f"[{self.text}]({self.url})"


class CategoryMetadata:
    def __init__(self, url, title, categories):
        self.url = url
        self.title = title
        self.categories = categories


class MetadataScrapper(Scrapper):
    def __init__(self, profile_id, outdir, headless=True):
        super().__init__(profile_id, headless)
        self.outdir = Path(outdir).resolve()
        self.categories_dir = self.outdir / "categories"
        self.recordings_dir = self.outdir / "recordings"
        self.queue = Queue()
        self.visited = set()
        self.all = set()

    
    async def open(self):
        print(f"[MetadataScrapper-{self.id}] Starting with profile [{self.profile_id}]...")
        self.browser = await launch(
            headless=self.headless,
            executablePath=CHROMIUM_PATH,
            userDataDir=self.profile_path)
        pages = await self.browser.pages()
        self.page = pages[0]

    async def close(self):
        print(f"[MetadataScrapper-{self.id}] Terminating...")
        await self.browser.close()


    async def crawl(self):
        await self.initialize()
        
        while not self.queue.empty():
            await asyncio.sleep(REQUEST_DELAY)
            url = self.queue.get()
            await self.process_resource_url(url)
            self.queue.task_done()


    async def initialize(self):
        self.log(f"Initializing...")
        self.queue = Queue()
        self.visited = set()
        self.all = set()

        self.categories_dir.mkdir(parents=True, exist_ok=True)
        self.recordings_dir.mkdir(parents=True, exist_ok=True)
        
        await self.page.goto(CATEGORIES_URL)
        urls = await self.queue_resource_urls()   

    
    async def queue_resource_urls(self):
        count = 0
        new = 0
        for url in await self.extract_resource_urls():
            self.all.add(url)
            count += 1
            if url not in self.visited:
                self.queue.put(url)
                new += 1
        self.log(f"Found {count} URLs ({new} new).")

    
    async def process_resource_url(self, url):
        self.log(f"Scrapping [{url}]...")
        await self.page.goto(url)

        self.visited.add(url)
        await self.queue_resource_urls()

        if is_category_url(url) or is_serie_url(url):
            await self.extract_category_metadata()
        elif is_recording_url(url):
            await self.extract_recording_metadata()


    async def extract_category_metadata(self):
        url = await self.page.evaluate('() => window.location.href')
        breadcrumbs = await page.xpath("//ul[@class='uk-breadcrumb']//li")
        title = await scrapper.get_text(breadcrumbs[-1])
        categories = await self.extract_parent_categories()

        data = {
            "url": url,
            "title": title,
            "categories": [{ "url": l.url, "title": l.text } for l in categories],
        }

        filename = safe_filename(f"{title}.yaml")
        filepath = self.categories_dir / filename

        with open(filepath, "w") as f:
            yaml.dump(data, f, sort_keys=False)

        self.log(f"Extracted category metadata in file [{filepath}].")


    async def extract_parent_categories(self):
        breadcrumbs = await page.xpath("//ul[@class='uk-breadcrumb']//li")     
        categories = []
        for elem in breadcrumbs[2:-1]:
            a = (await elem.xpath(".//a"))[0]
            url = await (await a.getProperty("href")).jsonValue()
            text = await (await a.getProperty("textContent")).jsonValue()
            categories.append(Link(url, text))

        return categories
    

    async def extract_recording_metadata(self):
        url = await self.page.evaluate('() => window.location.href')
        
        breadcrumbs = await page.xpath("//ul[@class='uk-breadcrumb']//li")
        title = await scrapper.get_text(breadcrumbs[-1])
        categories = await self.extract_parent_categories()
        
        title2 = await self.get_first("//h1[preceding-sibling::*[2][self::h3]]")
        subtitle = await self.get_first("//h2[preceding-sibling::*[3][self::h3]]")

        details = await page.xpath("//ul[@id='details']//li[@class='uk-active']//dd")
        code = (await self.get_text(details[0])).strip()
        date = (await self.get_text(details[-4])).strip()
        place = (await self.get_text(details[-3])).strip()
        authors = [s.strip() for s in (await self.get_text(details[-2])).split("<br/>")]
        duration_str = (await self.get_text(details[-1])).strip()

        summary = await scrapper.get_first("//li[@class='PromptuairePublication']//p")

        data = {
            "url": url,
            "code": code,
            "title": title2 or title,
            "subtitle": subtitle,
            "categories": [{ "url": l.url, "title": l.text } for l in categories],
            "date": date,
            "place": place,
            "authors": authors,
            "duration": duration_str,
            "duration-seconds": parse_duration(duration_str).seconds,
            "summary": summary,
        }

        record_dir = self.recordings_dir / safe_filename(f"{code}-{title}")
        record_dir.mkdir(parents=True, exist_ok=True)
        filepath = record_dir / "metadata.yaml"

        with open(filepath, "w") as f:
            yaml.dump(data, f, sort_keys=False)

        self.log(f"Extracted recording metadata in file [{filepath}].")
        

    async def extract_resource_urls(self):
        urls = []
        for elem in await page.xpath("//a"):
            url = await (await elem.getProperty("href")).jsonValue()
            urls.append(cleanup_url(url))
            
        resources = [u for u in urls if is_category_url(u) or is_serie_url(u) or is_recording_url(u)]
        return list(set(resources))  # dedup
    

    def log(self, msg):
        print(f"[MetadataScrapper-{self.id}] {msg}")

# %%
profile = "sndx-profile-1"
outdir = Path("/home/maxime/.local/share/sndx")

scrapper = MetadataScrapper(profile, outdir, headless=False)
await scrapper.open()
browser = scrapper.browser
page = scrapper.page
# Out:
# [MetadataScrapper-N4AKOA] Starting with profile [sndx-profile-1]...
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target
../metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/quand-un-pape-brandira-evangile-face-aux-nations-le-monde-connaitra-la-paix.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 4 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/ACT_1977_D_CEMBRE-Quand_un_pape_brandira_l_Evangile_face_aux.../metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-confirmation.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_3-Le_sacrement_de_confirmation/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-confirmation.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_3-Le_sacrement_de_confirmation/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-ordre.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_6-Le_sacrement_de_l_Ordre/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-ordre.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_6-Le_sacrement_de_l_Ordre/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/les-mysteres-chretiens.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_1-Les_myst_res_chr_tiens/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/les-mysteres-chretiens.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_1-Les_myst_res_chr_tiens/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-bapteme.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_2-Le_sacrement_de_bapt_me/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-bapteme.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_2-Le_sacrement_de_bapt_me/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-eucharistie.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_5-Le_sacrement_de_l_Eucharistie/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-eucharistie.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_5-Le_sacrement_de_l_Eucharistie/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-penitence.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_4-Le_sacrement_de_p_nitence/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-penitence.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_4-Le_sacrement_de_p_nitence/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-mariage.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_7-Le_sacrement_de_mariage/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-sacrement-de-mariage.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_7-Le_sacrement_de_mariage/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/onction-des-malades.html?media=a]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (1 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_8-L_onction_des_malades/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/onction-des-malades.html?media=v]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (0 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/SC_8-L_onction_des_malades/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/serie/saint-frere-andre-raconte-aux-enfants.html]...
# [MetadataScrapper-N4AKOA] Found 12 URLs (8 new).
# [MetadataScrapper-N4AKOA] Extracted category metadata in file [/home/maxime/.local/share/sndx/categories/Saint_fr_re_Andr_racont_aux_enfants.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-frere-marie-victorin.html]...
# [MetadataScrapper-N4AKOA] Found 6 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/PI_8_13-Le_fr_re_Marie-Victorin/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/le-cure-hebert-a-origine-de-la-colonisation-du-saguenay-lac-saint-jean.html]...
# [MetadataScrapper-N4AKOA] Found 6 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/PI_4_29-Le_cur_H_bert/metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/serie/mgr-ignace-bourget-raconte-aux-enfants.html]...
# [MetadataScrapper-N4AKOA] Found 8 URLs (4 new).
# [MetadataScrapper-N4AKOA] Extracted category metadata in file [/home/maxime/.local/share/sndx/categories/Mgr_Ignace_Bourget_racont_aux_enfants.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/un-tournant-missionnaire-reussi.html]...
# [MetadataScrapper-N4AKOA] Found 6 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/PI_8_12-Un_tournant_missionnaire_r_ussi_le.../metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/serie/le-jeu-de-saint-laurent-du-fleuve.html]...
# [MetadataScrapper-N4AKOA] Found 5 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted category metadata in file [/home/maxime/.local/share/sndx/categories/Le_jeu_de_saint_Laurent_du_fleuve.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/serie/sainte-marie-leonie.html]...
# [MetadataScrapper-N4AKOA] Found 6 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted category metadata in file [/home/maxime/.local/share/sndx/categories/Sainte_Marie-L_onie.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/mgr-norbert-provencher-pere-de-eglise-de-ouest-canadien.html]...
# [MetadataScrapper-N4AKOA] Found 6 URLs (2 new).
# [MetadataScrapper-N4AKOA] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/PI_3_11-Mgr_Norbert_Provencher_p_re_de_l_glise_de.../metadata.yaml].
# [MetadataScrapper-N4AKOA] Scrapping [https://vod.catalogue-crc.org/enregistrement/mere-marie-du-saint-esprit.html]...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await scrapper.crawl()
#
# Cell In[2], line 61, in MetadataScrapper.crawl(self)
#      59 await asyncio.sleep(REQUEST_DELAY)
#      60 url = self.queue.get()
# ---> 61 await self.process_resource_url(url)
#      62 self.queue.task_done()
#
# Cell In[2], line 92, in MetadataScrapper.process_resource_url(self, url)
#      90 async def process_resource_url(self, url):
#      91     self.log(f"Scrapping [{url}]...")
# ---> 92     await self.page.goto(url)
#      94     self.visited.add(url)
#      95     await self.queue_resource_urls()
#
# File ~/dev/python/sndx/.venv/lib/python3.12/site-packages/pyppeteer/page.py:833, in Page.goto(self, url, options, **kwargs)
#     831 if result is not None:
#     832     raise PageError(result)
# --> 833 result = await watcher.navigationPromise()
#     834 watcher.cancel()
#     835 helper.removeEventListeners(eventListeners)
#
# File /nix/store/jd20rkmqmkfkcvk2wl2lmzz7acq4svlr-python3-3.12.12/lib/python3.12/asyncio/tasks.py:464, in wait(fs, timeout, return_when)
#     461     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     463 loop = events.get_running_loop()
# --> 464 return await _wait(fs, timeout, return_when, loop)
#
# File /nix/store/jd20rkmqmkfkcvk2wl2lmzz7acq4svlr-python3-3.12.12/lib/python3.12/asyncio/tasks.py:550, in _wait(fs, timeout, return_when, loop)
#     547     f.add_done_callback(_on_completion)
#     549 try:
# --> 550     await waiter
#     551 finally:
#     552     if timeout_handle is not None:
#
# CancelledError:

# %%
scrapper.all
# Out:
# {'https://vod.catalogue-crc.org/categorie/apologetique-scientifique.html',
#  'https://vod.catalogue-crc.org/categorie/apologetique-totale.html',
#  'https://vod.catalogue-crc.org/categorie/apologetique.html',
#  'https://vod.catalogue-crc.org/categorie/canada.html',
#  'https://vod.catalogue-crc.org/categorie/cercle-saint-joseph.html',
#  'https://vod.catalogue-crc.org/categorie/conferences-de-frere-pierre.html',
#  'https://vod.catalogue-crc.org/categorie/eglise-malade-du-concile.html',
#  'https://vod.catalogue-crc.org/categorie/enseignement-catholique-et-la-revolution-tranquille.html',
#  'https://vod.catalogue-crc.org/categorie/epopee-des-missionnaires-o-m-i-au-canada.html',
#  'https://vod.catalogue-crc.org/categorie/frere-bruno.html',
#  'https://vod.catalogue-crc.org/categorie/grandes-reunions-annuelles-a-paris.html',
#  'https://vod.catalogue-crc.org/categorie/histoire-volontaire-de-la-sainte-et-doulce-france.html',
#  'https://vod.catalogue-crc.org/categorie/i-la-contre-reforme-dans-actualite.html',
#  'https://vod.catalogue-crc.org/categorie/ii-une-ecole-de-pensee.html',
#  'https://vod.catalogue-crc.org/categorie/iii-une-oeuvre-missionnaire.html',
#  'https://vod.catalogue-crc.org/categorie/iv-une-ecole-du-service-de-dieu.html',
#  'https://vod.catalogue-crc.org/categorie/kerygmatique.html',
#  'https://vod.catalogue-crc.org/categorie/la-guerre-de-1939-1945.html',
#  'https://vod.catalogue-crc.org/categorie/la-phalange-catholique.html',
#  'https://vod.catalogue-crc.org/categorie/la-tres-sainte-vierge.html',
#  'https://vod.catalogue-crc.org/categorie/la-vie-de-la-ligue.html',
#  'https://vod.catalogue-crc.org/categorie/les-actualites-politiques-et-religieuses.html',
#  'https://vod.catalogue-crc.org/categorie/les-actualites-religieuses.html',
#  'https://vod.catalogue-crc.org/categorie/les-grandes-crises-de-eglise.html',
#  'https://vod.catalogue-crc.org/categorie/les-grands-affrontements-du-siecle.html',
#  'https://vod.catalogue-crc.org/categorie/les-grands-debats-de-ce-temps.html',
#  'https://vod.catalogue-crc.org/categorie/les-oeuvres-de-frere-henry.html',
#  'https://vod.catalogue-crc.org/categorie/les-sacrements.html',
#  'https://vod.catalogue-crc.org/categorie/les-saintes-religieuses-canadiennes.html',
#  'https://vod.catalogue-crc.org/categorie/les-saints-eveques-pretres-et-religieux-canadiens.html',
#  'https://vod.catalogue-crc.org/categorie/logia-regroupes.html',
#  'https://vod.catalogue-crc.org/categorie/metaphysique-totale.html',
#  'https://vod.catalogue-crc.org/categorie/mission-et-colonisation.html',
#  'https://vod.catalogue-crc.org/categorie/morale-totale.html',
#  'https://vod.catalogue-crc.org/categorie/notre-doctrine-totale.html',
#  'https://vod.catalogue-crc.org/categorie/pelerinages-et-vies-des-saints.html',
#  'https://vod.catalogue-crc.org/categorie/philosophie.html',
#  'https://vod.catalogue-crc.org/categorie/politique-totale.html',
#  'https://vod.catalogue-crc.org/categorie/preparer-vatican-iii.html',
#  'https://vod.catalogue-crc.org/categorie/saint-pie-x.html',
#  'https://vod.catalogue-crc.org/categorie/spiritualite-et-vie-des-saints.html',
#  'https://vod.catalogue-crc.org/categorie/spiritualite.html',
#  'https://vod.catalogue-crc.org/categorie/theatre-crc.html',
#  'https://vod.catalogue-crc.org/categorie/theatre-et-art.html',
#  'https://vod.catalogue-crc.org/categorie/theologie-totale.html',
#  'https://vod.catalogue-crc.org/categorie/une-mystique-pour-notre-temps.html',
#  'https://vod.catalogue-crc.org/categorie/vie-et-saintete-en-nouvelle-france.html',
#  'https://vod.catalogue-crc.org/categorie/vie-sociale-politique-et-ecologique.html',
#  'https://vod.catalogue-crc.org/enregistrement/avenement-cim.html',
#  'https://vod.catalogue-crc.org/enregistrement/charles-de-foucauld.html',
#  'https://vod.catalogue-crc.org/enregistrement/elie-le-zele-jaloux-de-la-gloire-de-dieu.html',
#  'https://vod.catalogue-crc.org/enregistrement/esther-ou-immaculee-mediatrice.html',
#  'https://vod.catalogue-crc.org/enregistrement/evangile-de-jesus-christ.html',
#  'https://vod.catalogue-crc.org/enregistrement/fatima-les-trois-confidents-de-notre-dame.html',
#  'https://vod.catalogue-crc.org/enregistrement/fatima.html',
#  'https://vod.catalogue-crc.org/enregistrement/histoire-de-joseph.html',
#  'https://vod.catalogue-crc.org/enregistrement/la-nouvelle-droite.html',
#  'https://vod.catalogue-crc.org/enregistrement/la-religion-biblique.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-coeur-immacule-de-marie-regente-de-russie.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-livre-des-martyrs-d-israel.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-marechal-petain-et-les-corporations.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-mystere-du-coeur-immacule-de-marie.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-saint-roi-david.html',
#  'https://vod.catalogue-crc.org/enregistrement/le-secret-de-la-franc-maconnerie.html',
#  'https://vod.catalogue-crc.org/enregistrement/les-mysteres-douloureux-du-saint-rosaire.html',
#  'https://vod.catalogue-crc.org/enregistrement/les-mysteres-joyeux-du-saint-rosaire.html',
#  'https://vod.catalogue-crc.org/enregistrement/miracle-subsistant-utopie-realisee.html',
#  'https://vod.catalogue-crc.org/enregistrement/oratorio-SteJdA.html',
#  'https://vod.catalogue-crc.org/enregistrement/oratorio-les-mysteres-glorieux-du-saint-rosaire.html',
#  'https://vod.catalogue-crc.org/enregistrement/oratorio-saint-louis.html',
#  'https://vod.catalogue-crc.org/enregistrement/oratorio-unique-coeur.html',
#  'https://vod.catalogue-crc.org/enregistrement/saint-louis-marie-grignion-de-montfort.html',
#  'https://vod.catalogue-crc.org/enregistrement/saint-paul-apotre-et-martyr-grandes-tribulations.html',
#  'https://vod.catalogue-crc.org/enregistrement/saint-paul-apotre-et-martyr-le-sacrifice.html',
#  'https://vod.catalogue-crc.org/enregistrement/saint-paul-apotre-et-martyr.html',
#  'https://vod.catalogue-crc.org/enregistrement/sainte-cecile-vierge-et-martyre-oratorio.html',
#  'https://vod.catalogue-crc.org/enregistrement/sainte-marie-au-pays-des-hurons-enregistrement.html',
#  'https://vod.catalogue-crc.org/enregistrement/sainte-therese-de-enfant-jesus-victime-de-amour-misericordieux.html',
#  'https://vod.catalogue-crc.org/enregistrement/un-nouveau-judaisme.html',
#  'https://vod.catalogue-crc.org/serie/ame-humaine.html',
#  'https://vod.catalogue-crc.org/serie/existence-de-dieu.html',
#  'https://vod.catalogue-crc.org/serie/islam.html',
#  'https://vod.catalogue-crc.org/serie/la-confession-d-augsbourg.html',
#  'https://vod.catalogue-crc.org/serie/la-fin-du-monde.html',
#  'https://vod.catalogue-crc.org/serie/la-politique-et-la-foi-maurras-chretien.html',
#  'https://vod.catalogue-crc.org/serie/le-jesus-de-histoire-pascal-sous-la-toise.html',
#  'https://vod.catalogue-crc.org/serie/le-probleme-de-la-foi.html',
#  'https://vod.catalogue-crc.org/serie/le-saint-sacrifice-de-la-messe.html',
#  'https://vod.catalogue-crc.org/serie/viie-centenaire-de-saint-thomas.html'}

# %%
await scrapper.process_resource_url("https://vod.catalogue-crc.org/enregistrement/rene-bazin-mgr-freppel-et-la-gerbe-angevine.html")
# Out:
# [MetadataScrapper-IRwI6g] Scrapping [https://vod.catalogue-crc.org/enregistrement/rene-bazin-mgr-freppel-et-la-gerbe-angevine.html]...
# [MetadataScrapper-IRwI6g] Found 16 new resource URLs.
# [MetadataScrapper-IRwI6g] Extracted recording metadata in file [/home/maxime/.local/share/sndx/recordings/L_122-Ren_Bazin_Mgr_Freppel_et_la_gerbe_angevine/metadata.yaml].

# %%
print(f"Queued: {scrapper.queue.qsize()}")
print(f"Visited: {len(scrapper.visited)}")
# Out:
# Queued: 4549
# Visited: 184

# %%
summary = await scrapper.get_first("//li[@class='PromptuairePublication']//p")
summary
# Out:
# 'C’est un véritable roman d’aventure que la vie du frère Flavien Laplante, missionnaire au Bangladesh\xa0! Dans cette première partie, frère Pierre raconte la jeunesse, l’affermissement de la vocation et les débuts missionnaires de ce religieux canadien, bien selon le cœur du pape François. Mais quel est le secret de ce travailleur acharné, ami des humbles, bâtisseur et directeur d’école... terreur des pirates\xa0? L’amour de la Sainte Vierge.'

# %%
await scrapper.close()
# Out:
# [MetadataScrapper-PPuNfg] Terminating...

# %%
await page.xpath("//li[@class='PromptuairePublication']//p")

# %%
s = set()
s.add("auie")

# %%
s.add("auie")
s
# Out:
# {'auie'}
